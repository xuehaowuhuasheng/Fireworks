# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('AQI_Data.csv')

# %%
data.head(n=50)
# Out:
#      city  AQI PM2.5 PM10 SO2 NO2   CO  O3 main_pollution                 time
# 0     北京市   61    14   71   3  12  0.3  61           PM10  2019-02-04 00:00:00
# 1     天津市  104    41  157   8  21  0.9  53           PM10  2019-02-04 00:00:00
# 2    石家庄市  125    36  200  12  47  0.9  30           PM10  2019-02-04 00:00:00
# 3     唐山市   66    42   81  22  16  1.0  52           PM10  2019-02-04 00:00:00
# 4    秦皇岛市   55    25   60  12  22  0.9  48           PM10  2019-02-04 00:00:00
# 5     邯郸市  240   190  329  31  62  2.5  14          PM2.5  2019-02-04 00:00:00
# 6     邢台市  254   204  300  26  61  2.2  18          PM2.5  2019-02-04 00:00:00
# 7     保定市  102    42  153   6  18  0.7  54           PM10  2019-02-04 00:00:00
# 8     承德市   61    19   72   7  19  0.8  39           PM10  2019-02-04 00:00:00
# 9     沧州市  109    43  167  23  19  1.0  51           PM10  2019-02-04 00:00:00
# 10    廊坊市   68    22   85   4  16  0.5  56           PM10  2019-02-04 00:00:00
# 11    衡水市  190   143  227  24  30  1.6  56          PM2.5  2019-02-04 00:00:00
# 12   张家口市   58    22   66   9   9  0.6  63           PM10  2019-02-04 00:00:00
# 13    太原市   92    37  134  17  28  0.7  50           PM10  2019-02-04 00:00:00
# 14    大同市  103    30  156  17  10  0.5  70           PM10  2019-02-04 00:00:00
# 15    阳泉市   68    33   85  12  13  0.5  67           PM10  2019-02-04 00:00:00
# 16    长治市   60    30   70  26  36  1.0  49           PM10  2019-02-04 00:00:00
# 17    晋城市   62    14   73  12  13  0.5  76           PM10  2019-02-04 00:00:00
# 18    朔州市   85    18  119  10   7  0.4  77           PM10  2019-02-04 00:00:00
# 19    晋中市   90    59  130  72  40  1.0  30           PM10  2019-02-04 00:00:00
# 20    运城市  104    63  157  34  53  1.3  27           PM10  2019-02-04 00:00:00
# 21    忻州市   69    20   87  20  12  0.5  75           PM10  2019-02-04 00:00:00
# 22    临汾市   77    56  102  60  38  1.4  30          PM2.5  2019-02-04 00:00:00
# 23    吕梁市   89    49  127  76  26  0.8  38           PM10  2019-02-04 00:00:00
# 24  呼和浩特市   96    31  142  16  19  0.8  54           PM10  2019-02-04 00:00:00
# 25    包头市   86    44  122  28  49  1.4  29           PM10  2019-02-04 00:00:00
# 26    乌海市   77    35  104  28  20  1.0  56           PM10  2019-02-04 00:00:00
# 27    赤峰市   49    24   49  20  12  0.5  52              —  2019-02-04 00:00:00
# 28    通辽市   41    27   41   9   6  0.2  59              —  2019-02-04 00:00:00
# 29  鄂尔多斯市   80    22  110   9  12  0.6  69           PM10  2019-02-04 00:00:00
# 30  呼伦贝尔市   35    24   32   4   5  0.0  61              —  2019-02-04 00:00:00
# 31  巴彦淖尔市  100    32  150  10   8  0.6  64           PM10  2019-02-04 00:00:00
# 32  乌兰察布市   82    24  114  19   6  0.3  85           PM10  2019-02-04 00:00:00
# 33    兴安盟   30    21   27   6   7  0.3  58              —  2019-02-04 00:00:00
# 34  锡林郭勒盟   16     7   16   8   2  0.2  49              —  2019-02-04 00:00:00
# 35   阿拉善盟   63    32   76   8   6  0.5  88           PM10  2019-02-04 00:00:00
# 36    沈阳市   57    22   64  12  14  0.5  55           PM10  2019-02-04 00:00:00
# 37    大连市   58    23   66  10  10  0.6  63           PM10  2019-02-04 00:00:00
# 38   瓦房店市   62    19   74  18  20  0.7  60           PM10  2019-02-04 00:00:00
# 39    鞍山市   71    34   91  27  25  1.2  47           PM10  2019-02-04 00:00:00
# 40    抚顺市   55     9   60  10   6  0.4  67           PM10  2019-02-04 00:00:00
# 41    本溪市   59    19   68  12  10  0.8  56           PM10  2019-02-04 00:00:00
# 42    丹东市   61    32   72  12   8  0.5  62           PM10  2019-02-04 00:00:00
# 43    锦州市   32    16   32  31  16  0.8  55              —  2019-02-04 00:00:00
# 44    营口市   57    23   64  10  13  0.8  51           PM10  2019-02-04 00:00:00
# 45    阜新市   40    20   40  14   9  0.5  53              —  2019-02-04 00:00:00
# 46    辽阳市   68    28   86  10  16  0.6  47           PM10  2019-02-04 00:00:00
# 47    盘锦市   38    14   38  11  10  0.9  57              —  2019-02-04 00:00:00
# 48    铁岭市   44    12   44   5   8  0.3  62              —  2019-02-04 00:00:00
# 49    朝阳市   55    38   60  31  22  1.2  36           PM10  2019-02-04 00:00:00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71825 entries, 0 to 71824
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            71825 non-null  object
#  1   AQI             71825 non-null  object
#  2   PM2.5           71825 non-null  object
#  3   PM10            71825 non-null  object
#  4   SO2             71825 non-null  object
#  5   NO2             71825 non-null  object
#  6   CO              71825 non-null  object
#  7   O3              71825 non-null  object
#  8   main_pollution  71825 non-null  object
#  9   time            71825 non-null  object
# dtypes: object(10)
# memory usage: 5.5+ MB

# %%
data['time'].unique()
# Out:
# array(['2019-02-04 00:00:00', '2019-02-04 01:00:00',
#        '2019-02-04 02:00:00', '2019-02-04 03:00:00',
#        '2019-02-04 04:00:00', '2019-02-04 05:00:00',
#        '2019-02-04 06:00:00', '2019-02-04 07:00:00',
#        '2019-02-04 08:00:00', '2019-02-04 09:00:00',
#        '2019-02-04 10:00:00', '2019-02-04 11:00:00',
#        '2019-02-04 12:00:00', '2019-02-04 13:00:00',
#        '2019-02-04 14:00:00', '2019-02-04 15:00:00',
#        '2019-02-04 16:00:00', '2019-02-04 17:00:00',
#        '2019-02-04 18:00:00', '2019-02-04 19:00:00',
#        '2019-02-04 20:00:00', '2019-02-04 21:00:00',
#        '2019-02-04 22:00:00', '2019-02-04 23:00:00',
#        '2019-02-05 00:00:00', '2019-02-05 01:00:00',
#        '2019-02-05 02:00:00', '2019-02-05 03:00:00',
#        '2019-02-05 04:00:00', '2019-02-05 05:00:00',
#        '2019-02-05 06:00:00', '2019-02-05 07:00:00',
#        '2019-02-05 08:00:00', '2019-02-05 09:00:00',
#        '2019-02-05 10:00:00', '2019-02-05 11:00:00',
#        '2019-02-05 12:00:00', '2019-02-05 13:00:00',
#        '2019-02-05 14:00:00', '2019-02-05 15:00:00',
#        '2019-02-05 16:00:00', '2019-02-05 17:00:00',
#        '2019-02-05 18:00:00', '2019-02-05 19:00:00',
#        '2019-02-05 20:00:00', '2019-02-05 21:00:00',
#        '2019-02-05 22:00:00', '2019-02-05 23:00:00',
#        '2019-02-06 00:00:00', '2019-02-06 01:00:00',
#        '2019-02-06 02:00:00', '2019-02-06 03:00:00',
#        '2019-02-06 04:00:00', '2019-02-06 05:00:00',
#        '2019-02-06 06:00:00', '2019-02-06 07:00:00',
#        '2019-02-06 08:00:00', '2019-02-06 09:00:00',
#        '2019-02-06 10:00:00', '2019-02-06 11:00:00',
#        '2019-02-06 12:00:00', '2019-02-06 13:00:00',
#        '2019-02-06 14:00:00', '2019-02-06 15:00:00',
#        '2019-02-06 16:00:00', '2019-02-06 17:00:00',
#        '2019-02-06 18:00:00', '2019-02-06 19:00:00',
#        '2019-02-06 20:00:00', '2019-02-06 21:00:00',
#        '2019-02-06 22:00:00', '2019-02-06 23:00:00',
#        '2019-02-07 00:00:00', '2019-02-07 01:00:00',
#        '2019-02-07 02:00:00', '2019-02-07 03:00:00',
#        '2019-02-07 04:00:00', '2019-02-07 05:00:00',
#        '2019-02-07 06:00:00', '2019-02-07 07:00:00',
#        '2019-02-07 08:00:00', '2019-02-07 09:00:00',
#        '2019-02-07 10:00:00', '2019-02-07 11:00:00',
#        '2019-02-07 12:00:00', '2019-02-07 13:00:00',
#        '2019-02-07 14:00:00', '2019-02-07 15:00:00',
#        '2019-02-07 16:00:00', '2019-02-07 17:00:00',
#        '2019-02-07 18:00:00', '2019-02-07 19:00:00',
#        '2019-02-07 20:00:00', '2019-02-07 21:00:00',
#        '2019-02-07 22:00:00', '2019-02-07 23:00:00',
#        '2019-02-08 00:00:00', '2019-02-08 01:00:00',
#        '2019-02-08 02:00:00', '2019-02-08 03:00:00',
#        '2019-02-08 04:00:00', '2019-02-08 05:00:00',
#        '2019-02-08 06:00:00', '2019-02-08 07:00:00',
#        '2019-02-08 08:00:00', '2019-02-08 09:00:00',
#        '2019-02-08 10:00:00', '2019-02-08 11:00:00',
#        '2019-02-08 12:00:00', '2019-02-08 13:00:00',
#        '2019-02-08 14:00:00', '2019-02-08 15:00:00',
#        '2019-02-08 16:00:00', '2019-02-08 17:00:00',
#        '2019-02-08 18:00:00', '2019-02-08 19:00:00',
#        '2019-02-08 20:00:00', '2019-02-08 21:00:00',
#        '2019-02-08 22:00:00', '2019-02-08 23:00:00',
#        '2019-02-09 00:00:00', '2019-02-09 01:00:00',
#        '2019-02-09 02:00:00', '2019-02-09 03:00:00',
#        '2019-02-09 04:00:00', '2019-02-09 05:00:00',
#        '2019-02-09 06:00:00', '2019-02-09 07:00:00',
#        '2019-02-09 08:00:00', '2019-02-09 09:00:00',
#        '2019-02-09 10:00:00', '2019-02-09 11:00:00',
#        '2019-02-09 12:00:00', '2019-02-09 13:00:00',
#        '2019-02-09 14:00:00', '2019-02-09 15:00:00',
#        '2019-02-09 16:00:00', '2019-02-09 17:00:00',
#        '2019-02-09 18:00:00', '2019-02-09 19:00:00',
#        '2019-02-09 20:00:00', '2019-02-09 21:00:00',
#        '2019-02-09 22:00:00', '2019-02-09 23:00:00',
#        '2019-02-10 00:00:00', '2019-02-10 01:00:00',
#        '2019-02-10 02:00:00', '2019-02-10 03:00:00',
#        '2019-02-10 04:00:00', '2019-02-10 05:00:00',
#        '2019-02-10 06:00:00', '2019-02-10 07:00:00',
#        '2019-02-10 08:00:00', '2019-02-10 09:00:00',
#        '2019-02-10 10:00:00', '2019-02-10 11:00:00',
#        '2019-02-10 12:00:00', '2019-02-10 13:00:00',
#        '2019-02-10 14:00:00', '2019-02-10 15:00:00',
#        '2019-02-10 16:00:00', '2019-02-10 17:00:00',
#        '2019-02-10 18:00:00', '2019-02-10 19:00:00',
#        '2019-02-10 20:00:00', '2019-02-10 21:00:00',
#        '2019-02-10 22:00:00', '2019-02-10 23:00:00',
#        '2019-02-11 00:00:00', '2019-02-11 01:00:00',
#        '2019-02-11 02:00:00', '2019-02-11 03:00:00',
#        '2019-02-11 04:00:00', '2019-02-11 05:00:00',
#        '2019-02-11 06:00:00', '2019-02-11 07:00:00',
#        '2019-02-11 08:00:00', '2019-02-11 09:00:00',
#        '2019-02-11 10:00:00', '2019-02-11 11:00:00',
#        '2019-02-11 12:00:00', '2019-02-11 13:00:00',
#        '2019-02-11 14:00:00', '2019-02-11 15:00:00',
#        '2019-02-11 16:00:00', '2019-02-11 17:00:00',
#        '2019-02-11 18:00:00', '2019-02-11 19:00:00',
#        '2019-02-11 20:00:00', '2019-02-11 21:00:00',
#        '2019-02-11 22:00:00', '2019-02-11 23:00:00',
#        '2019-02-12 00:00:00', '2019-02-12 01:00:00',
#        '2019-02-12 02:00:00', '2019-02-12 03:00:00',
#        '2019-02-12 04:00:00', '2019-02-12 05:00:00',
#        '2019-02-12 06:00:00', '2019-02-12 07:00:00',
#        '2019-02-12 08:00:00', '2019-02-12 09:00:00'], dtype=object)

# %%
# 数据清洗
data['time'] = pd.to_datetime(data['time'])
data = data[data['time']<=pd.to_datetime('2019-02-11 23:59:59')]  # 选取2月4日——2月12日的数据
data.set_index(data["city"], inplace=False)
data = data.replace('—', np.nan)
for col in ['AQI', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']:
    data[col] = data[col].astype(float)
data.head()
# Out:
#    city    AQI  PM2.5   PM10   SO2   NO2   CO    O3 main_pollution       time
# 0   北京市   61.0   14.0   71.0   3.0  12.0  0.3  61.0           PM10 2019-02-04
# 1   天津市  104.0   41.0  157.0   8.0  21.0  0.9  53.0           PM10 2019-02-04
# 2  石家庄市  125.0   36.0  200.0  12.0  47.0  0.9  30.0           PM10 2019-02-04
# 3   唐山市   66.0   42.0   81.0  22.0  16.0  1.0  52.0           PM10 2019-02-04
# 4  秦皇岛市   55.0   25.0   60.0  12.0  22.0  0.9  48.0           PM10 2019-02-04

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68155 entries, 0 to 68154
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            68155 non-null  object
#  1   AQI             67903 non-null  float64
#  2   PM2.5           67815 non-null  float64
#  3   PM10            66437 non-null  float64
#  4   SO2             67832 non-null  float64
#  5   NO2             67852 non-null  float64
#  6   CO              67838 non-null  float64
#  7   O3              67842 non-null  float64
#  8   main_pollution  41176 non-null  object
#  9   time            68155 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), object(2)
# memory usage: 5.7+ MB

# %%
len(data['city'].unique())
# Out:
# 367

# %%
data.to_csv('data_clean.csv', index=False)

# %% [markdown]
# #### 一、数据详情
# - 共有68155条数据，时间为2月4日到2月11日，每隔1小时收集一次，囊括全国367个城市
# - 包含字段：城市、空气质量指数、PM2.5指数、PM10指数、SO2指数、NO2指数、CO指数、O3指数、主要污染源、时间
#
# #### 二、问题
# 1. 燃放烟花爆竹真的对空气质量有影响吗？
# 2. 烟花爆竹对空气质量的影响体现在哪些指标上？
# 3. 烟花爆竹对空气质量的污染程度有多大？
# 4. 哪些区域污染最严重(轻)？
# 5. 哪些城市属于一秒破功型？
# 6. 除夕中午到初一中午的超标城市个数
# 7. 除夕到初七的超标城市个数

# %% [markdown]
# ##### 1. 燃放烟花爆竹真的对空气质量有影响吗？

# %%
AQI_total_mean = data[data['time']<=pd.to_datetime('2019-02-06 23:59:59')].groupby(['time'])['AQI'].mean()

# %%
from pyecharts import Line 

line = Line("全国春节期间空气质量指数总体趋势", "2019年除夕到初二", width=800)
line.add("", AQI_total_mean.index, np.round(AQI_total_mean.values,0), is_smooth=True, 
         legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
         xaxis_rotate=20, yaxis_min=8, mark_point=["max"])
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f9714b0b030a476ca3f9203b32da6372" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f9714b0b030a476ca3f9203b32da6372 = echarts.init(document.getElementById('f9714b0b030a476ca3f9203b32da6372'), 'light', {renderer: 'canvas'});
#
# var option_f9714b0b030a476ca3f9203b32da6372 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570\u603b\u4f53\u8d8b\u52bf",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2885388,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2019-02-04T00:00:00",
#                     95.0
#                 ],
#                 [
#                     "2019-02-04T01:00:00",
#                     95.0
#                 ],
#                 [
#                     "2019-02-04T02:00:00",
#                     93.0
#                 ],
#                 [
#                     "2019-02-04T03:00:00",
#                     92.0
#                 ],
#                 [
#                     "2019-02-04T04:00:00",
#                     90.0
#                 ],
#                 [
#                     "2019-02-04T05:00:00",
#                     88.0
#                 ],
#                 [
#                     "2019-02-04T06:00:00",
#                     87.0
#                 ],
#                 [
#                     "2019-02-04T07:00:00",
#                     86.0
#                 ],
#                 [
#                     "2019-02-04T08:00:00",
#                     86.0
#                 ],
#                 [
#                     "2019-02-04T09:00:00",
#                     90.0
#                 ],
#                 [
#                     "2019-02-04T10:00:00",
#                     94.0
#                 ],
#                 [
#                     "2019-02-04T11:00:00",
#                     94.0
#                 ],
#                 [
#                     "2019-02-04T12:00:00",
#                     94.0
#                 ],
#                 [
#                     "2019-02-04T13:00:00",
#                     91.0
#                 ],
#                 [
#                     "2019-02-04T14:00:00",
#                     87.0
#                 ],
#                 [
#                     "2019-02-04T15:00:00",
#                     85.0
#                 ],
#                 [
#                     "2019-02-04T16:00:00",
#                     85.0
#                 ],
#                 [
#                     "2019-02-04T17:00:00",
#                     84.0
#                 ],
#                 [
#                     "2019-02-04T18:00:00",
#                     87.0
#                 ],
#                 [
#                     "2019-02-04T19:00:00",
#                     93.0
#                 ],
#                 [
#                     "2019-02-04T20:00:00",
#                     101.0
#                 ],
#                 [
#                     "2019-02-04T21:00:00",
#                     113.0
#                 ],
#                 [
#                     "2019-02-04T22:00:00",
#                     122.0
#                 ],
#                 [
#                     "2019-02-04T23:00:00",
#                     129.0
#                 ],
#                 [
#                     "2019-02-05T00:00:00",
#                     142.0
#                 ],
#                 [
#                     "2019-02-05T01:00:00",
#                     167.0
#                 ],
#                 [
#                     "2019-02-05T02:00:00",
#                     177.0
#                 ],
#                 [
#                     "2019-02-05T03:00:00",
#                     160.0
#                 ],
#                 [
#                     "2019-02-05T04:00:00",
#                     150.0
#                 ],
#                 [
#                     "2019-02-05T05:00:00",
#                     141.0
#                 ],
#                 [
#                     "2019-02-05T06:00:00",
#                     138.0
#                 ],
#                 [
#                     "2019-02-05T07:00:00",
#                     137.0
#                 ],
#                 [
#                     "2019-02-05T08:00:00",
#                     143.0
#                 ],
#                 [
#                     "2019-02-05T09:00:00",
#                     151.0
#                 ],
#                 [
#                     "2019-02-05T10:00:00",
#                     151.0
#                 ],
#                 [
#                     "2019-02-05T11:00:00",
#                     145.0
#                 ],
#                 [
#                     "2019-02-05T12:00:00",
#                     136.0
#                 ],
#                 [
#                     "2019-02-05T13:00:00",
#                     124.0
#                 ],
#                 [
#                     "2019-02-05T14:00:00",
#                     112.0
#                 ],
#                 [
#                     "2019-02-05T15:00:00",
#                     104.0
#                 ],
#                 [
#                     "2019-02-05T16:00:00",
#                     99.0
#                 ],
#                 [
#                     "2019-02-05T17:00:00",
#                     96.0
#                 ],
#                 [
#                     "2019-02-05T18:00:00",
#                     97.0
#                 ],
#                 [
#                     "2019-02-05T19:00:00",
#                     100.0
#                 ],
#                 [
#                     "2019-02-05T20:00:00",
#                     104.0
#                 ],
#                 [
#                     "2019-02-05T21:00:00",
#                     110.0
#                 ],
#                 [
#                     "2019-02-05T22:00:00",
#                     113.0
#                 ],
#                 [
#                     "2019-02-05T23:00:00",
#                     114.0
#                 ],
#                 [
#                     "2019-02-06T00:00:00",
#                     113.0
#                 ],
#                 [
#                     "2019-02-06T01:00:00",
#                     111.0
#                 ],
#                 [
#                     "2019-02-06T02:00:00",
#                     110.0
#                 ],
#                 [
#                     "2019-02-06T03:00:00",
#                     107.0
#                 ],
#                 [
#                     "2019-02-06T04:00:00",
#                     105.0
#                 ],
#                 [
#                     "2019-02-06T05:00:00",
#                     101.0
#                 ],
#                 [
#                     "2019-02-06T06:00:00",
#                     98.0
#                 ],
#                 [
#                     "2019-02-06T07:00:00",
#                     97.0
#                 ],
#                 [
#                     "2019-02-06T08:00:00",
#                     98.0
#                 ],

# %%
def city_AQI(data, cities):
    line = Line("春节期间空气质量指数", "2019年除夕到初二", width=800)
    for city in cities:
        city_aqi = data[(data['city']==city)&(data['time']<=pd.to_datetime('2019-02-06 23:59:59'))]
        line.add(city, city_aqi.index, np.round(city_aqi['AQI'].values,0), is_smooth=True, 
             legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
             xaxis_rotate=20, yaxis_min=8, mark_point=["max"])
    return line

# %%
city_AQI(data=data, cities=['北京市', '天津市'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b4ba4996c40046edb3cc809fde2638fd" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b4ba4996c40046edb3cc809fde2638fd = echarts.init(document.getElementById('b4ba4996c40046edb3cc809fde2638fd'), 'light', {renderer: 'canvas'});
#
# var option_b4ba4996c40046edb3cc809fde2638fd = {
#     "title": [
#         {
#             "text": "\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4811156,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5317\u4eac\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     0,
#                     61.0
#                 ],
#                 [
#                     367,
#                     56.0
#                 ],
#                 [
#                     734,
#                     53.0
#                 ],
#                 [
#                     1101,
#                     56.0
#                 ],
#                 [
#                     1468,
#                     55.0
#                 ],
#                 [
#                     1835,
#                     57.0
#                 ],
#                 [
#                     2202,
#                     71.0
#                 ],
#                 [
#                     2569,
#                     81.0
#                 ],
#                 [
#                     2936,
#                     78.0
#                 ],
#                 [
#                     3303,
#                     75.0
#                 ],
#                 [
#                     3670,
#                     73.0
#                 ],
#                 [
#                     4037,
#                     72.0
#                 ],
#                 [
#                     4404,
#                     72.0
#                 ],
#                 [
#                     4771,
#                     73.0
#                 ],
#                 [
#                     5138,
#                     76.0
#                 ],
#                 [
#                     5505,
#                     81.0
#                 ],
#                 [
#                     5872,
#                     85.0
#                 ],
#                 [
#                     6239,
#                     86.0
#                 ],
#                 [
#                     6606,
#                     88.0
#                 ],
#                 [
#                     6973,
#                     91.0
#                 ],
#                 [
#                     7340,
#                     95.0
#                 ],
#                 [
#                     7707,
#                     100.0
#                 ],
#                 [
#                     8074,
#                     109.0
#                 ],
#                 [
#                     8441,
#                     120.0
#                 ],
#                 [
#                     8808,
#                     124.0
#                 ],
#                 [
#                     9175,
#                     139.0
#                 ],
#                 [
#                     9542,
#                     175.0
#                 ],
#                 [
#                     9909,
#                     227.0
#                 ],
#                 [
#                     10276,
#                     221.0
#                 ],
#                 [
#                     10643,
#                     209.0
#                 ],
#                 [
#                     11010,
#                     183.0
#                 ],
#                 [
#                     11377,
#                     163.0
#                 ],
#                 [
#                     11744,
#                     143.0
#                 ],
#                 [
#                     12111,
#                     103.0
#                 ],
#                 [
#                     12478,
#                     89.0
#                 ],
#                 [
#                     12845,
#                     92.0
#                 ],
#                 [
#                     13212,
#                     114.0
#                 ],
#                 [
#                     13579,
#                     137.0
#                 ],
#                 [
#                     13946,
#                     148.0
#                 ],
#                 [
#                     14313,
#                     183.0
#                 ],
#                 [
#                     14680,
#                     196.0
#                 ],
#                 [
#                     15047,
#                     194.0
#                 ],
#                 [
#                     15414,
#                     181.0
#                 ],
#                 [
#                     15781,
#                     166.0
#                 ],
#                 [
#                     16148,
#                     143.0
#                 ],
#                 [
#                     16515,
#                     129.0
#                 ],
#                 [
#                     16882,
#                     133.0
#                 ],
#                 [
#                     17249,
#                     129.0
#                 ],
#                 [
#                     17616,
#                     122.0
#                 ],
#                 [
#                     17983,
#                     121.0
#                 ],
#                 [
#                     18350,
#                     118.0
#                 ],
#                 [
#                     18717,
#                     107.0
#                 ],
#                 [
#                     19084,
#                     98.0
#                 ],
#                 [
#                     19451,
#                     94.0
#                 ],
#                 [
#                     19818,
#                     93.0
#                 ],
#                 [
#                     20185,
#                     87.0
#                 ],
#                 [
#                     20552,
#                     79.0
#                 ],
#                 [
#                     20919,
#                     74.0
#                 ],
#                 [
#                     21286,
#                     70.0
#                 ],
#                 [
#                     21653,
#                     68.0
#                 ],
#                 [
#                     22020,
#                     70.0
#                 ],
#                 [
#                     22387,
#                     74.0
#                 ],
#                 [
#                     22754,
#                     77.0
#                 ],
#                 [
#                     23121,
#                     80.0
#                 ],
#                 [
#                     23488,
#                     85.0
#                 ],
#                 [
#                     23855,
#                     88.0
#                 ],
#                 [
#                     24222,
#                     90.0
#                 ],
#                 [
#                     24589,

# %%
city_AQI(data=data, cities=['长沙市', '南宁市'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="058370a75fb04159a462728209c40426" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_058370a75fb04159a462728209c40426 = echarts.init(document.getElementById('058370a75fb04159a462728209c40426'), 'light', {renderer: 'canvas'});
#
# var option_058370a75fb04159a462728209c40426 = {
#     "title": [
#         {
#             "text": "\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6095945,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u957f\u6c99\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     209,
#                     88.0
#                 ],
#                 [
#                     576,
#                     87.0
#                 ],
#                 [
#                     943,
#                     88.0
#                 ],
#                 [
#                     1310,
#                     87.0
#                 ],
#                 [
#                     1677,
#                     89.0
#                 ],
#                 [
#                     2044,
#                     93.0
#                 ],
#                 [
#                     2411,
#                     97.0
#                 ],
#                 [
#                     2778,
#                     97.0
#                 ],
#                 [
#                     3145,
#                     99.0
#                 ],
#                 [
#                     3512,
#                     102.0
#                 ],
#                 [
#                     3879,
#                     112.0
#                 ],
#                 [
#                     4246,
#                     124.0
#                 ],
#                 [
#                     4613,
#                     129.0
#                 ],
#                 [
#                     4980,
#                     134.0
#                 ],
#                 [
#                     5347,
#                     140.0
#                 ],
#                 [
#                     5714,
#                     145.0
#                 ],
#                 [
#                     6081,
#                     155.0
#                 ],
#                 [
#                     6448,
#                     162.0
#                 ],
#                 [
#                     6815,
#                     172.0
#                 ],
#                 [
#                     7182,
#                     185.0
#                 ],
#                 [
#                     7549,
#                     200.0
#                 ],
#                 [
#                     7916,
#                     212.0
#                 ],
#                 [
#                     8283,
#                     215.0
#                 ],
#                 [
#                     8650,
#                     209.0
#                 ],
#                 [
#                     9017,
#                     217.0
#                 ],
#                 [
#                     9384,
#                     270.0
#                 ],
#                 [
#                     9751,
#                     285.0
#                 ],
#                 [
#                     10118,
#                     300.0
#                 ],
#                 [
#                     10485,
#                     268.0
#                 ],
#                 [
#                     10852,
#                     271.0
#                 ],
#                 [
#                     11219,
#                     251.0
#                 ],
#                 [
#                     11586,
#                     230.0
#                 ],
#                 [
#                     11953,
#                     230.0
#                 ],
#                 [
#                     12320,
#                     226.0
#                 ],
#                 [
#                     12687,
#                     219.0
#                 ],
#                 [
#                     13054,
#                     212.0
#                 ],
#                 [
#                     13421,
#                     189.0
#                 ],
#                 [
#                     13788,
#                     142.0
#                 ],
#                 [
#                     14155,
#                     124.0
#                 ],
#                 [
#                     14522,
#                     129.0
#                 ],
#                 [
#                     14889,
#                     137.0
#                 ],
#                 [
#                     15256,
#                     139.0
#                 ],
#                 [
#                     15623,
#                     147.0
#                 ],
#                 [
#                     15990,
#                     159.0
#                 ],
#                 [
#                     16357,
#                     185.0
#                 ],
#                 [
#                     16724,
#                     202.0
#                 ],
#                 [
#                     17091,
#                     202.0
#                 ],
#                 [
#                     17458,
#                     183.0
#                 ],
#                 [
#                     17825,
#                     160.0
#                 ],
#                 [
#                     18192,
#                     147.0
#                 ],
#                 [
#                     18559,
#                     138.0
#                 ],
#                 [
#                     18926,
#                     127.0
#                 ],
#                 [
#                     19293,
#                     115.0
#                 ],
#                 [
#                     19660,
#                     100.0
#                 ],
#                 [
#                     20027,
#                     87.0
#                 ],
#                 [
#                     20394,
#                     78.0
#                 ],
#                 [
#                     20761,
#                     70.0
#                 ],
#                 [
#                     21128,
#                     67.0
#                 ],
#                 [
#                     21495,
#                     73.0
#                 ],
#                 [
#                     21862,
#                     75.0
#                 ],
#                 [
#                     22229,
#                     67.0
#                 ],
#                 [
#                     22596,
#                     60.0
#                 ],
#                 [
#                     22963,
#                     58.0
#                 ],
#                 [
#                     23330,
#                     58.0
#                 ],
#                 [
#                     23697,
#                     59.0
#                 ],
#                 [
#                     24064,
#                     63.0
#                 ],
#                 [
#                     24431,
#                     73.0
#                 ],
#                 [

# %% [markdown]
# ##### 2. 烟花爆竹对空气质量的影响体现在哪些指标上？

# %%
data_total_idx = data[data['time']<=pd.to_datetime('2019-02-06 23:59:59')].groupby(['time']).mean()

# %%
data_total_idx.columns
# Out:
# Index(['AQI', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3'], dtype='object')

# %%
line = Line("全国春节期间空气质量各指标（2019年除夕到初二）", "单位:μg/m3(CO为mg/m3)", width=800)
for idx in data_total_idx.columns[1:]:
    line.add(idx, data_total_idx.index, np.round(data_total_idx[idx].values,0), is_smooth=True, 
             legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
             xaxis_rotate=20, yaxis_min=8, legend_top=30)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="23b29e948cd84d36851b71829af62ee9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_23b29e948cd84d36851b71829af62ee9 = echarts.init(document.getElementById('23b29e948cd84d36851b71829af62ee9'), 'light', {renderer: 'canvas'});
#
# var option_23b29e948cd84d36851b71829af62ee9 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u5404\u6307\u6807\uff082019\u5e74\u9664\u5915\u5230\u521d\u4e8c\uff09",
#             "subtext": "\u5355\u4f4d:\u03bcg/m3(CO\u4e3amg/m3)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1800853,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "PM2.5",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2019-02-04T00:00:00",
#                     61.0
#                 ],
#                 [
#                     "2019-02-04T01:00:00",
#                     62.0
#                 ],
#                 [
#                     "2019-02-04T02:00:00",
#                     60.0
#                 ],
#                 [
#                     "2019-02-04T03:00:00",
#                     60.0
#                 ],
#                 [
#                     "2019-02-04T04:00:00",
#                     59.0
#                 ],
#                 [
#                     "2019-02-04T05:00:00",
#                     57.0
#                 ],
#                 [
#                     "2019-02-04T06:00:00",
#                     56.0
#                 ],
#                 [
#                     "2019-02-04T07:00:00",
#                     55.0
#                 ],
#                 [
#                     "2019-02-04T08:00:00",
#                     56.0
#                 ],
#                 [
#                     "2019-02-04T09:00:00",
#                     60.0
#                 ],
#                 [
#                     "2019-02-04T10:00:00",
#                     63.0
#                 ],
#                 [
#                     "2019-02-04T11:00:00",
#                     62.0
#                 ],
#                 [
#                     "2019-02-04T12:00:00",
#                     60.0
#                 ],
#                 [
#                     "2019-02-04T13:00:00",
#                     57.0
#                 ],
#                 [
#                     "2019-02-04T14:00:00",
#                     53.0
#                 ],
#                 [
#                     "2019-02-04T15:00:00",
#                     50.0
#                 ],
#                 [
#                     "2019-02-04T16:00:00",
#                     49.0
#                 ],
#                 [
#                     "2019-02-04T17:00:00",
#                     50.0
#                 ],
#                 [
#                     "2019-02-04T18:00:00",
#                     53.0
#                 ],
#                 [
#                     "2019-02-04T19:00:00",
#                     59.0
#                 ],
#                 [
#                     "2019-02-04T20:00:00",
#                     67.0
#                 ],
#                 [
#                     "2019-02-04T21:00:00",
#                     78.0
#                 ],
#                 [
#                     "2019-02-04T22:00:00",
#                     86.0
#                 ],
#                 [
#                     "2019-02-04T23:00:00",
#                     92.0
#                 ],
#                 [
#                     "2019-02-05T00:00:00",
#                     107.0
#                 ],
#                 [
#                     "2019-02-05T01:00:00",
#                     127.0
#                 ],
#                 [
#                     "2019-02-05T02:00:00",
#                     137.0
#                 ],
#                 [
#                     "2019-02-05T03:00:00",
#                     124.0
#                 ],
#                 [
#                     "2019-02-05T04:00:00",
#                     113.0
#                 ],
#                 [
#                     "2019-02-05T05:00:00",
#                     106.0
#                 ],
#                 [
#                     "2019-02-05T06:00:00",
#                     103.0
#                 ],
#                 [
#                     "2019-02-05T07:00:00",
#                     104.0
#                 ],
#                 [
#                     "2019-02-05T08:00:00",
#                     109.0
#                 ],
#                 [
#                     "2019-02-05T09:00:00",
#                     116.0
#                 ],
#                 [
#                     "2019-02-05T10:00:00",
#                     116.0
#                 ],
#                 [
#                     "2019-02-05T11:00:00",
#                     110.0
#                 ],
#                 [
#                     "2019-02-05T12:00:00",
#                     102.0
#                 ],
#                 [
#                     "2019-02-05T13:00:00",
#                     91.0
#                 ],
#                 [
#                     "2019-02-05T14:00:00",
#                     80.0
#                 ],
#                 [
#                     "2019-02-05T15:00:00",
#                     73.0
#                 ],
#                 [
#                     "2019-02-05T16:00:00",
#                     69.0
#                 ],
#                 [
#                     "2019-02-05T17:00:00",
#                     66.0
#                 ],
#                 [
#                     "2019-02-05T18:00:00",
#                     67.0
#                 ],
#                 [
#                     "2019-02-05T19:00:00",
#                     70.0
#                 ],
#                 [
#                     "2019-02-05T20:00:00",
#                     74.0
#                 ],
#                 [
#                     "2019-02-05T21:00:00",
#                     79.0
#                 ],
#                 [
#                     "2019-02-05T22:00:00",
#                     82.0
#                 ],
#                 [
#                     "2019-02-05T23:00:00",
#                     83.0
#                 ],
#                 [
#                     "2019-02-06T00:00:00",
#                     82.0
#                 ],
#                 [
#                     "2019-02-06T01:00:00",
#                     80.0
#                 ],
#                 [
#                     "2019-02-06T02:00:00",
#                     79.0
#                 ],
#                 [
#                     "2019-02-06T03:00:00",
#                     77.0
#                 ],
#                 [
#                     "2019-02-06T04:00:00",
#                     76.0
#                 ],
#                 [
#                     "2019-02-06T05:00:00",
#                     73.0
#                 ],
#                 [
#                     "2019-02-06T06:00:00",
#                     70.0
#                 ],
#                 [
#                     "2019-02-06T07:00:00",
#                     69.0
#                 ],
#                 [
#                     "2019-02-06T08:00:00",

# %%
tianjin_idx = data[(data['city']=='石家庄市')&(data['time']<=pd.to_datetime('2019-02-06 23:59:59'))]
line = Line("石家庄市春节期间空气质量各指标（2019年除夕到初二）", "单位:μg/m3(CO为mg/m3)", width=800)
for idx in tianjin_idx.columns[2:8]:
    line.add(idx, tianjin_idx.index, np.round(tianjin_idx[idx].values,0), is_smooth=True, 
             legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
             xaxis_rotate=20, yaxis_min=8, legend_top=30)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c8fac493b519406d9442a6cf9e2cedc0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c8fac493b519406d9442a6cf9e2cedc0 = echarts.init(document.getElementById('c8fac493b519406d9442a6cf9e2cedc0'), 'light', {renderer: 'canvas'});
#
# var option_c8fac493b519406d9442a6cf9e2cedc0 = {
#     "title": [
#         {
#             "text": "\u77f3\u5bb6\u5e84\u5e02\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u5404\u6307\u6807\uff082019\u5e74\u9664\u5915\u5230\u521d\u4e8c\uff09",
#             "subtext": "\u5355\u4f4d:\u03bcg/m3(CO\u4e3amg/m3)",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3509702,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "PM2.5",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     2,
#                     36.0
#                 ],
#                 [
#                     369,
#                     40.0
#                 ],
#                 [
#                     736,
#                     41.0
#                 ],
#                 [
#                     1103,
#                     74.0
#                 ],
#                 [
#                     1470,
#                     134.0
#                 ],
#                 [
#                     1837,
#                     128.0
#                 ],
#                 [
#                     2204,
#                     106.0
#                 ],
#                 [
#                     2571,
#                     92.0
#                 ],
#                 [
#                     2938,
#                     74.0
#                 ],
#                 [
#                     3305,
#                     62.0
#                 ],
#                 [
#                     3672,
#                     48.0
#                 ],
#                 [
#                     4039,
#                     42.0
#                 ],
#                 [
#                     4406,
#                     34.0
#                 ],
#                 [
#                     4773,
#                     33.0
#                 ],
#                 [
#                     5140,
#                     35.0
#                 ],
#                 [
#                     5507,
#                     40.0
#                 ],
#                 [
#                     5874,
#                     51.0
#                 ],
#                 [
#                     6241,
#                     77.0
#                 ],
#                 [
#                     6608,
#                     106.0
#                 ],
#                 [
#                     6975,
#                     122.0
#                 ],
#                 [
#                     7342,
#                     145.0
#                 ],
#                 [
#                     7709,
#                     186.0
#                 ],
#                 [
#                     8076,
#                     262.0
#                 ],
#                 [
#                     8443,
#                     220.0
#                 ],
#                 [
#                     8810,
#                     245.0
#                 ],
#                 [
#                     9177,
#                     262.0
#                 ],
#                 [
#                     9544,
#                     259.0
#                 ],
#                 [
#                     9911,
#                     229.0
#                 ],
#                 [
#                     10278,
#                     220.0
#                 ],
#                 [
#                     10645,
#                     203.0
#                 ],
#                 [
#                     11012,
#                     168.0
#                 ],
#                 [
#                     11379,
#                     154.0
#                 ],
#                 [
#                     11746,
#                     157.0
#                 ],
#                 [
#                     12113,
#                     167.0
#                 ],
#                 [
#                     12480,
#                     156.0
#                 ],
#                 [
#                     12847,
#                     141.0
#                 ],
#                 [
#                     13214,
#                     130.0
#                 ],
#                 [
#                     13581,
#                     116.0
#                 ],
#                 [
#                     13948,
#                     120.0
#                 ],
#                 [
#                     14315,
#                     114.0
#                 ],
#                 [
#                     14682,
#                     126.0
#                 ],
#                 [
#                     15049,
#                     149.0
#                 ],
#                 [
#                     15416,
#                     151.0
#                 ],
#                 [
#                     15783,
#                     169.0
#                 ],
#                 [
#                     16150,
#                     218.0
#                 ],
#                 [
#                     16517,
#                     178.0
#                 ],
#                 [
#                     16884,
#                     168.0
#                 ],
#                 [
#                     17251,
#                     148.0
#                 ],
#                 [
#                     17618,
#                     127.0
#                 ],
#                 [
#                     17985,
#                     87.0
#                 ],
#                 [
#                     18352,
#                     97.0
#                 ],
#                 [
#                     18719,
#                     101.0
#                 ],
#                 [
#                     19086,
#                     103.0
#                 ],
#                 [
#                     19453,
#                     101.0
#                 ],
#                 [
#                     19820,
#                     103.0
#                 ],
#                 [
#                     20187,
#                     102.0
#                 ],
#                 [
#                     20554,
#                     102.0
#                 ],
#                 [
#                     20921,
#                     100.0
#                 ],
#                 [
#                     21288,
#                     98.0
#                 ],
#                 [
#                     21655,
#                     101.0
#                 ],
#                 [
#                     22022,
#                     109.0
#                 ],
#                 [
#                     22389,
#                     107.0
#                 ],
#                 [
#                     22756,
#                     106.0
#                 ],
#                 [
#                     23123,
#                     104.0
#                 ],
#                 [
#                     23490,
#                     108.0
#                 ],
#                 [
#                     23857,
#                     99.0
#                 ],
#                 [
#                     24224,

# %%
main_pol = data.loc[data['time']==pd.to_datetime('2019-02-05 02:00:00'), 'main_pollution'].value_counts()

# %%
main_pol
# Out:
# PM2.5         243
# PM10           97
# PM10,PM2.5     10
# Name: main_pollution, dtype: int64

# %%
from pyecharts import Bar

bar = Bar("全国城市首要污染物", "2019年2月5日凌晨2点", width=600)
bar.add("", main_pol.index, main_pol.values, is_stack=True, is_label_show=True,
       bar_category_gap='40%', label_color = ['#130f40'], label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3e1dc34f34cb4179a053742e0918a6cb" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3e1dc34f34cb4179a053742e0918a6cb = echarts.init(document.getElementById('3e1dc34f34cb4179a053742e0918a6cb'), 'light', {renderer: 'canvas'});
#
# var option_3e1dc34f34cb4179a053742e0918a6cb = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u57ce\u5e02\u9996\u8981\u6c61\u67d3\u7269",
#             "subtext": "2019\u5e742\u67085\u65e5\u51cc\u66682\u70b9",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8395438,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 243.0,
#                 97.0,
#                 10.0
#             ],
#             "stack": "stack_8395438",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8395438
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             },
#             "data": [
#                 "PM2.5",
#                 "PM10",
#                 "PM10,PM2.5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#130f40",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_3e1dc34f34cb4179a053742e0918a6cb.setOption(option_3e1dc34f34cb4179a053742e0918a6cb);
#
#     });
# </script>

# %% [markdown]
# ##### 3. 烟花爆竹对空气质量的污染程度有多大？

# %%
data2 = data[data['time']<=pd.to_datetime('2019-02-05 23:59:59')]
data_AQI_min = data2.groupby('city')['AQI'].min()
data_AQI_max = data2.groupby('city')['AQI'].max()

# %%
data_AQI_times = np.round(data_AQI_max/data_AQI_min, 1)

# %%
data_AQI_times_top10 = data_AQI_times.nlargest(10)

# %%
bar = Bar("全国除夕和春节期间空气质量最高最低比Top10城市", "时间：2019年除夕至初一", width=600)
bar.add("", data_AQI_times_top10.index, data_AQI_times_top10.values, is_stack=True, 
        is_label_show=True,bar_category_gap='40%', label_color = ['#130f40'], label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18, xaxis_rotate=30)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="19fbdaba5afb4c5d819cbc75e037aed7" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_19fbdaba5afb4c5d819cbc75e037aed7 = echarts.init(document.getElementById('19fbdaba5afb4c5d819cbc75e037aed7'), 'light', {renderer: 'canvas'});
#
# var option_19fbdaba5afb4c5d819cbc75e037aed7 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u9664\u5915\u548c\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6700\u9ad8\u6700\u4f4e\u6bd4Top10\u57ce\u5e02",
#             "subtext": "\u65f6\u95f4\uff1a2019\u5e74\u9664\u5915\u81f3\u521d\u4e00",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8393741,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 22.7,
#                 22.7,
#                 21.4,
#                 20.4,
#                 19.2,
#                 17.9,
#                 17.2,
#                 16.7,
#                 16.1,
#                 16.1
#             ],
#             "stack": "stack_8393741",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8393741
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 14
#                 }
#             },
#             "data": [
#                 "\u4f0a\u6625\u5e02",
#                 "\u9e21\u897f\u5e02",
#                 "\u9521\u6797\u90ed\u52d2\u76df",
#                 "\u5927\u5174\u5b89\u5cad\u5730\u533a",
#                 "\u7389\u6811\u5dde",
#                 "\u76d8\u9526\u5e02",
#                 "\u846b\u82a6\u5c9b\u5e02",
#                 "\u7518\u5357\u5dde",
#                 "\u74e6\u623f\u5e97\u5e02",
#                 "\u9526\u5dde\u5e02"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#130f40",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_19fbdaba5afb4c5d819cbc75e037aed7.setOption(option_19fbdaba5afb4c5d819cbc75e037aed7);
#
#     });
# </script>

# %%
data_AQI_times_top10
# Out:
# city
# 伊春市       22.7
# 鸡西市       22.7
# 锡林郭勒盟     21.4
# 大兴安岭地区    20.4
# 玉树州       19.2
# 盘锦市       17.9
# 葫芦岛市      17.2
# 甘南州       16.7
# 瓦房店市      16.1
# 锦州市       16.1
# Name: AQI, dtype: float64

# %%
city_AQI(data=data, cities=['伊春市','鸡西市', '大兴安岭地区'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0fa658027aca459788a3332ce38a75e8" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0fa658027aca459788a3332ce38a75e8 = echarts.init(document.getElementById('0fa658027aca459788a3332ce38a75e8'), 'light', {renderer: 'canvas'});
#
# var option_0fa658027aca459788a3332ce38a75e8 = {
#     "title": [
#         {
#             "text": "\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8535434,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4f0a\u6625\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     66,
#                     32.0
#                 ],
#                 [
#                     433,
#                     28.0
#                 ],
#                 [
#                     800,
#                     26.0
#                 ],
#                 [
#                     1167,
#                     26.0
#                 ],
#                 [
#                     1534,
#                     26.0
#                 ],
#                 [
#                     1901,
#                     28.0
#                 ],
#                 [
#                     2268,
#                     33.0
#                 ],
#                 [
#                     2635,
#                     40.0
#                 ],
#                 [
#                     3002,
#                     69.0
#                 ],
#                 [
#                     3369,
#                     78.0
#                 ],
#                 [
#                     3736,
#                     42.0
#                 ],
#                 [
#                     4103,
#                     36.0
#                 ],
#                 [
#                     4470,
#                     29.0
#                 ],
#                 [
#                     4837,
#                     27.0
#                 ],
#                 [
#                     5204,
#                     30.0
#                 ],
#                 [
#                     5571,
#                     40.0
#                 ],
#                 [
#                     5938,
#                     32.0
#                 ],
#                 [
#                     6305,
#                     32.0
#                 ],
#                 [
#                     6672,
#                     36.0
#                 ],
#                 [
#                     7039,
#                     49.0
#                 ],
#                 [
#                     7406,
#                     62.0
#                 ],
#                 [
#                     7773,
#                     72.0
#                 ],
#                 [
#                     8140,
#                     77.0
#                 ],
#                 [
#                     8507,
#                     54.0
#                 ],
#                 [
#                     8874,
#                     500.0
#                 ],
#                 [
#                     9241,
#                     236.0
#                 ],
#                 [
#                     9608,
#                     87.0
#                 ],
#                 [
#                     9975,
#                     72.0
#                 ],
#                 [
#                     10342,
#                     67.0
#                 ],
#                 [
#                     10709,
#                     62.0
#                 ],
#                 [
#                     11076,
#                     60.0
#                 ],
#                 [
#                     11443,
#                     52.0
#                 ],
#                 [
#                     11810,
#                     50.0
#                 ],
#                 [
#                     12177,
#                     63.0
#                 ],
#                 [
#                     12544,
#                     68.0
#                 ],
#                 [
#                     12911,
#                     48.0
#                 ],
#                 [
#                     13278,
#                     32.0
#                 ],
#                 [
#                     13645,
#                     22.0
#                 ],
#                 [
#                     14012,
#                     36.0
#                 ],
#                 [
#                     14379,
#                     42.0
#                 ],
#                 [
#                     14746,
#                     38.0
#                 ],
#                 [
#                     15113,
#                     39.0
#                 ],
#                 [
#                     15480,
#                     42.0
#                 ],
#                 [
#                     15847,
#                     40.0
#                 ],
#                 [
#                     16214,
#                     43.0
#                 ],
#                 [
#                     16581,
#                     46.0
#                 ],
#                 [
#                     16948,
#                     41.0
#                 ],
#                 [
#                     17315,
#                     40.0
#                 ],
#                 [
#                     17682,
#                     43.0
#                 ],
#                 [
#                     18049,
#                     44.0
#                 ],
#                 [
#                     18416,
#                     42.0
#                 ],
#                 [
#                     18783,
#                     36.0
#                 ],
#                 [
#                     19150,
#                     32.0
#                 ],
#                 [
#                     19517,
#                     29.0
#                 ],
#                 [
#                     19884,
#                     29.0
#                 ],
#                 [
#                     20251,
#                     43.0
#                 ],
#                 [
#                     20618,
#                     49.0
#                 ],
#                 [
#                     20985,
#                     54.0
#                 ],
#                 [
#                     21352,
#                     45.0
#                 ],
#                 [
#                     21719,
#                     39.0
#                 ],
#                 [
#                     22086,
#                     24.0
#                 ],
#                 [
#                     22453,
#                     19.0
#                 ],
#                 [
#                     22820,
#                     20.0
#                 ],
#                 [
#                     23187,
#                     20.0
#                 ],
#                 [
#                     23554,
#                     19.0
#                 ],
#                 [
#                     23921,
#                     28.0
#                 ],
#                 [
#                     24288,
#                     35.0
#                 ],
#                 [
#                     24655,
#                     48.0

# %%
city_AQI(data=data, cities=['盘锦市','葫芦岛市','瓦房店市','锦州市'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7077ad93063a4419a9d209ce31d326aa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7077ad93063a4419a9d209ce31d326aa = echarts.init(document.getElementById('7077ad93063a4419a9d209ce31d326aa'), 'light', {renderer: 'canvas'});
#
# var option_7077ad93063a4419a9d209ce31d326aa = {
#     "title": [
#         {
#             "text": "\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2977469,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u76d8\u9526\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     47,
#                     38.0
#                 ],
#                 [
#                     414,
#                     29.0
#                 ],
#                 [
#                     781,
#                     33.0
#                 ],
#                 [
#                     1148,
#                     38.0
#                 ],
#                 [
#                     1515,
#                     42.0
#                 ],
#                 [
#                     1882,
#                     40.0
#                 ],
#                 [
#                     2249,
#                     37.0
#                 ],
#                 [
#                     2616,
#                     50.0
#                 ],
#                 [
#                     2983,
#                     68.0
#                 ],
#                 [
#                     3350,
#                     125.0
#                 ],
#                 [
#                     3717,
#                     135.0
#                 ],
#                 [
#                     4084,
#                     264.0
#                 ],
#                 [
#                     4451,
#                     169.0
#                 ],
#                 [
#                     4818,
#                     79.0
#                 ],
#                 [
#                     5185,
#                     68.0
#                 ],
#                 [
#                     5552,
#                     87.0
#                 ],
#                 [
#                     5919,
#                     97.0
#                 ],
#                 [
#                     6286,
#                     132.0
#                 ],
#                 [
#                     6653,
#                     287.0
#                 ],
#                 [
#                     7020,
#                     206.0
#                 ],
#                 [
#                     7387,
#                     209.0
#                 ],
#                 [
#                     7754,
#                     173.0
#                 ],
#                 [
#                     8121,
#                     205.0
#                 ],
#                 [
#                     8488,
#                     255.0
#                 ],
#                 [
#                     8855,
#                     325.0
#                 ],
#                 [
#                     9222,
#                     500.0
#                 ],
#                 [
#                     9589,
#                     200.0
#                 ],
#                 [
#                     9956,
#                     85.0
#                 ],
#                 [
#                     10323,
#                     75.0
#                 ],
#                 [
#                     10690,
#                     62.0
#                 ],
#                 [
#                     11057,
#                     57.0
#                 ],
#                 [
#                     11424,
#                     41.0
#                 ],
#                 [
#                     11791,
#                     29.0
#                 ],
#                 [
#                     12158,
#                     28.0
#                 ],
#                 [
#                     12525,
#                     36.0
#                 ],
#                 [
#                     12892,
#                     45.0
#                 ],
#                 [
#                     13259,
#                     54.0
#                 ],
#                 [
#                     13626,
#                     68.0
#                 ],
#                 [
#                     13993,
#                     58.0
#                 ],
#                 [
#                     14360,
#                     64.0
#                 ],
#                 [
#                     14727,
#                     73.0
#                 ],
#                 [
#                     15094,
#                     87.0
#                 ],
#                 [
#                     15461,
#                     92.0
#                 ],
#                 [
#                     15828,
#                     79.0
#                 ],
#                 [
#                     16195,
#                     64.0
#                 ],
#                 [
#                     16562,
#                     54.0
#                 ],
#                 [
#                     16929,
#                     63.0
#                 ],
#                 [
#                     17296,
#                     70.0
#                 ],
#                 [
#                     17663,
#                     53.0
#                 ],
#                 [
#                     18030,
#                     47.0
#                 ],
#                 [
#                     18397,
#                     63.0
#                 ],
#                 [
#                     18764,
#                     79.0
#                 ],
#                 [
#                     19131,
#                     77.0
#                 ],
#                 [
#                     19498,
#                     65.0
#                 ],
#                 [
#                     19865,
#                     64.0
#                 ],
#                 [
#                     20232,
#                     78.0
#                 ],
#                 [
#                     20599,
#                     107.0
#                 ],
#                 [
#                     20966,
#                     142.0
#                 ],
#                 [
#                     21333,
#                     138.0
#                 ],
#                 [
#                     21700,
#                     85.0
#                 ],
#                 [
#                     22067,
#                     84.0
#                 ],
#                 [
#                     22434,
#                     63.0
#                 ],
#                 [
#                     22801,
#                     64.0
#                 ],
#                 [
#                     23168,
#                     63.0
#                 ],
#                 [
#                     23535,
#                     58.0
#                 ],
#                 [
#                     23902,
#                     54.0
#                 ],
#                 [
#                     24269,
#                     47.0
#                 ],
#                 [
#                     24636,
#                     43.

# %%
data_AQI_times_counts = data_AQI_times.value_counts(bins=[1,5,10,15,20,25])
data_AQI_times_counts
# Out:
# (0.999, 5.0]    238
# (5.0, 10.0]      88
# (10.0, 15.0]     28
# (15.0, 20.0]      9
# (20.0, 25.0]      4
# Name: AQI, dtype: int64

# %%
bar = Bar("全国除夕和春节期间空气质量最高最低比的城市数量", "时间：2019年除夕至初一", width=600)
times = ['1-5倍','5-10倍','10-15倍','15-20倍','20-25倍']
bar.add("", times, data_AQI_times_counts.values, is_stack=True, 
        is_label_show=True,bar_category_gap='40%', label_color = ['#130f40'], label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c93f503a1d6a4968b6b3ed36bea96ef9" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c93f503a1d6a4968b6b3ed36bea96ef9 = echarts.init(document.getElementById('c93f503a1d6a4968b6b3ed36bea96ef9'), 'light', {renderer: 'canvas'});
#
# var option_c93f503a1d6a4968b6b3ed36bea96ef9 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u9664\u5915\u548c\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6700\u9ad8\u6700\u4f4e\u6bd4\u7684\u57ce\u5e02\u6570\u91cf",
#             "subtext": "\u65f6\u95f4\uff1a2019\u5e74\u9664\u5915\u81f3\u521d\u4e00",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 851860,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 238.0,
#                 88.0,
#                 28.0,
#                 9.0,
#                 4.0
#             ],
#             "stack": "stack_851860",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 851860
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             },
#             "data": [
#                 "1-5\u500d",
#                 "5-10\u500d",
#                 "10-15\u500d",
#                 "15-20\u500d",
#                 "20-25\u500d"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#130f40",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_c93f503a1d6a4968b6b3ed36bea96ef9.setOption(option_c93f503a1d6a4968b6b3ed36bea96ef9);
#
#     });
# </script>

# %% [markdown]
# ##### 4. 哪些区域污染最严重（轻）？

# %%
start_time = pd.to_datetime('2019-02-04 20:00:00')
end_time = pd.to_datetime('2019-02-05 04:00:00')
AQI_by_city = data[(data['time']>=start_time)&(data['time']<=end_time)].groupby('city')['AQI'].mean()

# %%
from pyecharts import Geo

geo = Geo(
    "全国各城市空气质量指数",
    "除夕晚上20点至初一凌晨4点平均值",
    title_color="#fff",
    title_pos="center",
    width=800,
    height=500,
    background_color="#404a59",
)
attr, value = AQI_by_city.index, AQI_by_city.values

geo.add(
    "",
    attr,
    value,
    visual_range=[0, 500],
    visual_text_color="#fff",
    symbol_size=10,
    is_visualmap=True,
    is_piecewise=True,
    visual_split_number=10,
)
geo

# %%
AQI_by_city.nlargest(10)
# Out:
# city
# 阿克苏地区    454.333333
# 库尔勒市     436.111111
# 呼和浩特市    394.333333
# 和田地区     357.666667
# 安康市      343.888889
# 白山市      340.333333
# 亳州市      320.333333
# 喀什地区     320.111111
# 包头市      295.666667
# 咸阳市      288.222222
# Name: AQI, dtype: float64

# %%
city_AQI(data=data, cities=['呼和浩特市', '包头市', '咸阳市'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d449da68d5814b8a903fd10994593392" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d449da68d5814b8a903fd10994593392 = echarts.init(document.getElementById('d449da68d5814b8a903fd10994593392'), 'light', {renderer: 'canvas'});
#
# var option_d449da68d5814b8a903fd10994593392 = {
#     "title": [
#         {
#             "text": "\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1983650,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u547c\u548c\u6d69\u7279\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     24,
#                     96.0
#                 ],
#                 [
#                     391,
#                     87.0
#                 ],
#                 [
#                     758,
#                     87.0
#                 ],
#                 [
#                     1125,
#                     85.0
#                 ],
#                 [
#                     1492,
#                     85.0
#                 ],
#                 [
#                     1859,
#                     86.0
#                 ],
#                 [
#                     2226,
#                     85.0
#                 ],
#                 [
#                     2593,
#                     83.0
#                 ],
#                 [
#                     2960,
#                     84.0
#                 ],
#                 [
#                     3327,
#                     88.0
#                 ],
#                 [
#                     3694,
#                     91.0
#                 ],
#                 [
#                     4061,
#                     95.0
#                 ],
#                 [
#                     4428,
#                     92.0
#                 ],
#                 [
#                     4795,
#                     94.0
#                 ],
#                 [
#                     5162,
#                     105.0
#                 ],
#                 [
#                     5529,
#                     172.0
#                 ],
#                 [
#                     5896,
#                     222.0
#                 ],
#                 [
#                     6263,
#                     231.0
#                 ],
#                 [
#                     6630,
#                     225.0
#                 ],
#                 [
#                     6997,
#                     219.0
#                 ],
#                 [
#                     7364,
#                     254.0
#                 ],
#                 [
#                     7731,
#                     300.0
#                 ],
#                 [
#                     8098,
#                     310.0
#                 ],
#                 [
#                     8465,
#                     338.0
#                 ],
#                 [
#                     8832,
#                     349.0
#                 ],
#                 [
#                     9199,
#                     498.0
#                 ],
#                 [
#                     9566,
#                     500.0
#                 ],
#                 [
#                     9933,
#                     500.0
#                 ],
#                 [
#                     10300,
#                     500.0
#                 ],
#                 [
#                     10667,
#                     428.0
#                 ],
#                 [
#                     11034,
#                     331.0
#                 ],
#                 [
#                     11401,
#                     276.0
#                 ],
#                 [
#                     11768,
#                     216.0
#                 ],
#                 [
#                     12135,
#                     169.0
#                 ],
#                 [
#                     12502,
#                     165.0
#                 ],
#                 [
#                     12869,
#                     175.0
#                 ],
#                 [
#                     13236,
#                     166.0
#                 ],
#                 [
#                     13603,
#                     143.0
#                 ],
#                 [
#                     13970,
#                     123.0
#                 ],
#                 [
#                     14337,
#                     128.0
#                 ],
#                 [
#                     14704,
#                     129.0
#                 ],
#                 [
#                     15071,
#                     121.0
#                 ],
#                 [
#                     15438,
#                     131.0
#                 ],
#                 [
#                     15805,
#                     138.0
#                 ],
#                 [
#                     16172,
#                     103.0
#                 ],
#                 [
#                     16539,
#                     83.0
#                 ],
#                 [
#                     16906,
#                     75.0
#                 ],
#                 [
#                     17273,
#                     76.0
#                 ],
#                 [
#                     17640,
#                     92.0
#                 ],
#                 [
#                     18007,
#                     147.0
#                 ],
#                 [
#                     18374,
#                     325.0
#                 ],
#                 [
#                     18741,
#                     310.0
#                 ],
#                 [
#                     19108,
#                     217.0
#                 ],
#                 [
#                     19475,
#                     127.0
#                 ],
#                 [
#                     19842,
#                     100.0
#                 ],
#                 [
#                     20209,
#                     99.0
#                 ],
#                 [
#                     20576,
#                     104.0
#                 ],
#                 [
#                     20943,
#                     97.0
#                 ],
#                 [
#                     21310,
#                     83.0
#                 ],
#                 [
#                     21677,
#                     84.0
#                 ],
#                 [
#                     22044,
#                     89.0
#                 ],
#                 [
#                     22411,
#                     93.0
#                 ],
#                 [
#                     22778,
#                     84.0
#                 ],
#                 [
#                     23145,
#                     94.0
#                 ],
#                 [
#                     23512,
#                     97.0
#                 ],
#                 [
#                     23879,
#                     123.0
#                 ],
#                 [
#                     24246,
#                     119.0
#                 ],
#                 [

# %%
AQI_by_city.nsmallest(5)
# Out:
# city
# 义乌市      12.500000
# 阿勒泰地区    27.111111
# 攀枝花市     27.444444
# 丽江市      28.000000
# 阿里地区     28.222222
# Name: AQI, dtype: float64

# %%
AQI_by_city[AQI_by_city<=50]
# Out:
# city
# 中山市      41.555556
# 丽江市      28.000000
# 义乌市      12.500000
# 保山市      42.888889
# 嘉峪关市     34.888889
# 塔城地区     33.666667
# 大理州      41.444444
# 安顺市      39.333333
# 惠州市      47.333333
# 拉萨市      36.777778
# 揭阳市      45.222222
# 攀枝花市     27.444444
# 昆明市      48.666667
# 景德镇市     43.444444
# 林芝市      36.333333
# 武威市      47.777778
# 汕尾市      49.555556
# 江门市      42.555556
# 海北州      39.111111
# 海南州      44.333333
# 海口市      41.333333
# 海西州      46.333333
# 深圳市      44.777778
# 珠海市      48.777778
# 甘孜州      43.555556
# 迪庆州      39.111111
# 那曲地区     41.333333
# 金昌市      49.000000
# 阳江市      38.444444
# 阿勒泰地区    27.111111
# 阿坝州      41.222222
# 阿里地区     28.222222
# Name: AQI, dtype: float64

# %% [markdown]
# ##### 5. 哪些城市属于一秒破功型？

# %%
city1 = data.loc[(data['time'] == pd.to_datetime('2019-02-05 02:00:00'))&(data['AQI']<100), 'city']

# %%
data3 = data[(data['time'] >= pd.to_datetime('2019-02-05 18:00:00'))&
            (data['time'] <= pd.to_datetime('2019-02-06 23:59:59'))]

# %%
city2 = data3.loc[data3['AQI']>200, 'city']

# %%
list(set(city1).intersection(set(city2)))
# Out:
# ['长春市', '中卫市', '那曲地区', '铜川市', '忻州市', '白城市', '郑州市', '吴忠市', '晋城市']

# %%
city_AQI(data=data, cities=['郑州市', '长春市', '忻州市', '晋城市'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e2b0f7aa718c43d5ad71ce7a95863450" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e2b0f7aa718c43d5ad71ce7a95863450 = echarts.init(document.getElementById('e2b0f7aa718c43d5ad71ce7a95863450'), 'light', {renderer: 'canvas'});
#
# var option_e2b0f7aa718c43d5ad71ce7a95863450 = {
#     "title": [
#         {
#             "text": "\u6625\u8282\u671f\u95f4\u7a7a\u6c14\u8d28\u91cf\u6307\u6570",
#             "subtext": "2019\u5e74\u9664\u5915\u5230\u521d\u4e8c",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1526343,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u90d1\u5dde\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     179,
#                     72.0
#                 ],
#                 [
#                     546,
#                     70.0
#                 ],
#                 [
#                     913,
#                     70.0
#                 ],
#                 [
#                     1280,
#                     70.0
#                 ],
#                 [
#                     1647,
#                     70.0
#                 ],
#                 [
#                     2014,
#                     73.0
#                 ],
#                 [
#                     2381,
#                     77.0
#                 ],
#                 [
#                     2748,
#                     80.0
#                 ],
#                 [
#                     3115,
#                     82.0
#                 ],
#                 [
#                     3482,
#                     85.0
#                 ],
#                 [
#                     3849,
#                     88.0
#                 ],
#                 [
#                     4216,
#                     88.0
#                 ],
#                 [
#                     4583,
#                     87.0
#                 ],
#                 [
#                     4950,
#                     88.0
#                 ],
#                 [
#                     5317,
#                     86.0
#                 ],
#                 [
#                     5684,
#                     81.0
#                 ],
#                 [
#                     6051,
#                     83.0
#                 ],
#                 [
#                     6418,
#                     85.0
#                 ],
#                 [
#                     6785,
#                     80.0
#                 ],
#                 [
#                     7152,
#                     85.0
#                 ],
#                 [
#                     7519,
#                     89.0
#                 ],
#                 [
#                     7886,
#                     90.0
#                 ],
#                 [
#                     8253,
#                     87.0
#                 ],
#                 [
#                     8620,
#                     82.0
#                 ],
#                 [
#                     8987,
#                     80.0
#                 ],
#                 [
#                     9354,
#                     83.0
#                 ],
#                 [
#                     9721,
#                     92.0
#                 ],
#                 [
#                     10088,
#                     97.0
#                 ],
#                 [
#                     10455,
#                     97.0
#                 ],
#                 [
#                     10822,
#                     102.0
#                 ],
#                 [
#                     11189,
#                     105.0
#                 ],
#                 [
#                     11556,
#                     114.0
#                 ],
#                 [
#                     11923,
#                     118.0
#                 ],
#                 [
#                     12290,
#                     123.0
#                 ],
#                 [
#                     12657,
#                     132.0
#                 ],
#                 [
#                     13024,
#                     135.0
#                 ],
#                 [
#                     13391,
#                     142.0
#                 ],
#                 [
#                     13758,
#                     149.0
#                 ],
#                 [
#                     14125,
#                     160.0
#                 ],
#                 [
#                     14492,
#                     158.0
#                 ],
#                 [
#                     14859,
#                     140.0
#                 ],
#                 [
#                     15226,
#                     137.0
#                 ],
#                 [
#                     15593,
#                     201.0
#                 ],
#                 [
#                     15960,
#                     227.0
#                 ],
#                 [
#                     16327,
#                     246.0
#                 ],
#                 [
#                     16694,
#                     281.0
#                 ],
#                 [
#                     17061,
#                     288.0
#                 ],
#                 [
#                     17428,
#                     325.0
#                 ],
#                 [
#                     17795,
#                     381.0
#                 ],
#                 [
#                     18162,
#                     414.0
#                 ],
#                 [
#                     18529,
#                     412.0
#                 ],
#                 [
#                     18896,
#                     420.0
#                 ],
#                 [
#                     19263,
#                     455.0
#                 ],
#                 [
#                     19630,
#                     412.0
#                 ],
#                 [
#                     19997,
#                     391.0
#                 ],
#                 [
#                     20364,
#                     386.0
#                 ],
#                 [
#                     20731,
#                     365.0
#                 ],
#                 [
#                     21098,
#                     339.0
#                 ],
#                 [
#                     21465,
#                     310.0
#                 ],
#                 [
#                     21832,
#                     276.0
#                 ],
#                 [
#                     22199,
#                     252.0
#                 ],
#                 [
#                     22566,
#                     245.0
#                 ],
#                 [
#                     22933,
#                     241.0
#                 ],
#                 [
#                     23300,
#                     233.0
#                 ],
#                 [
#                     23667,
#                     231.0
#                 ],
#                 [
#                     24034,
#                     230.0
#                 ],
#                 [
#                     24401,
#                     226.0
#                 ],
#                 [
#                     24768,

# %% [markdown]
# ##### 6. 除夕中午到初一中午的超标城市个数

# %%
start_time = pd.to_datetime('2019-02-04 12:00:00')
end_time = pd.to_datetime('2019-02-05 12:00:00')

# %%
city_over_new_year = data.loc[(data['time']>=start_time)&(data['time']<=end_time)&(data['AQI']>100)].groupby('time')['AQI'].count()

# %%
from pyecharts import Overlap

bar = Bar("全国除夕中午至初一中午空气质量超标城市数量", "时间: 2019年  总城市数: 367", width=1000)
new_year_time = ['除夕12点','除夕13点','除夕14点','除夕15点','除夕16点','除夕17点','除夕18点','除夕19点',
        '除夕20点','除夕21点','除夕22点','除夕23点','春节0点','春节1点','春节2点','春节3点',
        '春节4点','春节5点','春节6点','春节7点','春节8点','春节9点','春节10点','春节11点','春节12点']
bar.add("", new_year_time, city_over_new_year.values, is_stack=True, 
        is_label_show=True,bar_category_gap='40%', label_color = ['#130f40'], label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18, xaxis_rotate=90)

line = Line("", width=1000)
line.add("", new_year_time, city_over_new_year.values+5, is_smooth=True)

overlap = Overlap(width=1000)
overlap.add(bar)
overlap.add(line)

overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bb1b4261b3d845a68d621f4cc56545c9" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bb1b4261b3d845a68d621f4cc56545c9 = echarts.init(document.getElementById('bb1b4261b3d845a68d621f4cc56545c9'), 'light', {renderer: 'canvas'});
#
# var option_bb1b4261b3d845a68d621f4cc56545c9 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u9664\u5915\u4e2d\u5348\u81f3\u521d\u4e00\u4e2d\u5348\u7a7a\u6c14\u8d28\u91cf\u8d85\u6807\u57ce\u5e02\u6570\u91cf",
#             "subtext": "\u65f6\u95f4: 2019\u5e74  \u603b\u57ce\u5e02\u6570: 367",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5294285,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 125.0,
#                 118.0,
#                 115.0,
#                 110.0,
#                 108.0,
#                 103.0,
#                 110.0,
#                 121.0,
#                 143.0,
#                 178.0,
#                 197.0,
#                 205.0,
#                 226.0,
#                 255.0,
#                 255.0,
#                 234.0,
#                 219.0,
#                 207.0,
#                 199.0,
#                 195.0,
#                 204.0,
#                 210.0,
#                 205.0,
#                 202.0,
#                 192.0
#             ],
#             "stack": "stack_5294285",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5294285
#         },
#         {
#             "type": "line",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u9664\u591512\u70b9",
#                     130.0
#                 ],
#                 [
#                     "\u9664\u591513\u70b9",
#                     123.0
#                 ],
#                 [
#                     "\u9664\u591514\u70b9",
#                     120.0
#                 ],
#                 [
#                     "\u9664\u591515\u70b9",
#                     115.0
#                 ],
#                 [
#                     "\u9664\u591516\u70b9",
#                     113.0
#                 ],
#                 [
#                     "\u9664\u591517\u70b9",
#                     108.0
#                 ],
#                 [
#                     "\u9664\u591518\u70b9",
#                     115.0
#                 ],
#                 [
#                     "\u9664\u591519\u70b9",
#                     126.0
#                 ],
#                 [
#                     "\u9664\u591520\u70b9",
#                     148.0
#                 ],
#                 [
#                     "\u9664\u591521\u70b9",
#                     183.0
#                 ],
#                 [
#                     "\u9664\u591522\u70b9",
#                     202.0
#                 ],
#                 [
#                     "\u9664\u591523\u70b9",
#                     210.0
#                 ],
#                 [
#                     "\u6625\u82820\u70b9",
#                     231.0
#                 ],
#                 [
#                     "\u6625\u82821\u70b9",
#                     260.0
#                 ],
#                 [
#                     "\u6625\u82822\u70b9",
#                     260.0
#                 ],
#                 [
#                     "\u6625\u82823\u70b9",
#                     239.0
#                 ],
#                 [
#                     "\u6625\u82824\u70b9",
#                     224.0
#                 ],
#                 [
#                     "\u6625\u82825\u70b9",
#                     212.0
#                 ],
#                 [
#                     "\u6625\u82826\u70b9",
#                     204.0
#                 ],
#                 [
#                     "\u6625\u82827\u70b9",
#                     200.0
#                 ],
#                 [
#                     "\u6625\u82828\u70b9",
#                     209.0
#                 ],
#                 [
#                     "\u6625\u82829\u70b9",
#                     215.0
#                 ],
#                 [
#                     "\u6625\u828210\u70b9",
#                     210.0
#                 ],
#                 [
#                     "\u6625\u828211\u70b9",
#                     207.0
#                 ],
#                 [
#                     "\u6625\u828212\u70b9",
#                     197.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5294285,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval":

# %% [markdown]
# ##### 7. 除夕到初七的超标城市个数

# %%
city_over_count = (data.groupby('city')['AQI'].resample('D').mean()>100).unstack(level=-1).sum()
city_over_count

# %%
bar = Bar("全国除夕至初七期间空气质量超标城市数量", "时间: 2019年  总城市数: 367", width=800)
date = ['02-04(除夕)','02-05(初一)','02-06(初二)','02-07(初三)',
        '02-08(初四)','02-09(初五)','02-10(初六)','02-11(初七)']
bar.add("", date, city_over_count.values, is_stack=True, 
        is_label_show=True,bar_category_gap='40%', label_color = ['#130f40'], label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18, xaxis_rotate=20)

line = Line("", width=800)
line.add("", date, city_over_count.values+5, is_smooth=True)

overlap = Overlap(width=700)
overlap.add(bar)
overlap.add(line)

overlap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-fa6f2fc0d656> in <module>()
#       2 date = ['02-04(除夕)','02-05(初一)','02-06(初二)','02-07(初三)',
#       3         '02-08(初四)','02-09(初五)','02-10(初六)','02-11(初七)']
# ----> 4 bar.add("", date, city_over_count.values, is_stack=True,
#       5         is_label_show=True,bar_category_gap='40%', label_color = ['#130f40'], label_text_size=18,
#       6        legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18, xaxis_rotate=20)
#
# NameError: name 'city_over_count' is not defined
